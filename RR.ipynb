# %%
import matplotlib.pyplot as plt

# %%
def raw_data_processing(file_path):
    doc=[]
    temp={}
    with open(file_path) as f:
        for line in f:
            content=line.rstrip().split('\t')
            if len(content)==1:
                doc.append(temp)
                temp={}
            else:
                if len(content[0].split(' '))==2:
                    if not content[0]+'_0' in temp:
                        temp[content[0]+'_0']=float(content[1])
                    else:
                        if content[0]+'_1' in temp:
                            temp[content[0]+'_2']=float(content[1])
                        else:
                            temp[content[0]+'_1']=float(content[1])
                else:
                    temp[content[0]]=float(content[1])
    return doc

def pickup(proc_bw_content_0,proc_bw_content_1,proc_bw_content_2,content):
    for i in content:
        proc_bw_content_0.append(i['real_bw_0'])
        proc_bw_content_1.append(i['real_bw_1'])
        proc_bw_content_2.append(i['real_bw_2'])
        
def smooth(proc_bw_content_0):
    for i in range(len(proc_bw_content_0)):
        if proc_bw_content_0[i] < 0.001:
            proc_bw_content_0[i]=0
        if proc_bw_content_0[i] > 100:
            proc_bw_content_0[i]=proc_bw_content_0[i-1]

def mysum(content_0,content_1,content_2,content_sum):
    for i in range(len(content_0)):
        content_sum.append(content_0[i]+content_1[i]+content_2[i])

# %%
file_path="C:\\Users\\ycy\\Desktop\\SS_Abstract_RR.dat"
content=raw_data_processing(file_path)

# %%
content
# Out:
# [{'Standard_NC_YCY_v1.0': 1208204041.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 10.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 20.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0990445,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 228.0,
#   'real_rx_packets_0': 228.0,
#   'real_bw_1': 0.101052,
#   'real_loss_1': 0.0,
#   'real_delay_1': 21.0,
#   'real_tx_packets_1': 227.0,
#   'real_rx_packets_1': 227.0,
#   'real_bw_2': 0.0980471,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 227.0,
#   'real_rx_packets_2': 227.0},
#  {'Standard_NC_YCY_v1.0': 1208204046.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.005,
#   'set delay_0': 40.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.005,
#   'set delay_1': 15.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.0539794,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 129.0,
#   'real_rx_packets_0': 128.0,
#   'real_bw_1': 0.0557563,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 128.0,
#   'real_rx_packets_1': 128.0,
#   'real_bw_2': 0.0539523,
#   'real_loss_2': 0.0,
#   'real_delay_2': 50.0,
#   'real_tx_packets_2': 128.0,
#   'real_rx_packets_2': 128.0},
#  {'Standard_NC_YCY_v1.0': 1208204050.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 5.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.005,
#   'set delay_1': 100.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0551376,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 130.0,
#   'real_rx_packets_0': 130.0,
#   'real_bw_1': 0.0542259,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 129.0,
#   'real_rx_packets_1': 128.0,
#   'real_bw_2': 0.0560648,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 129.0,
#   'real_rx_packets_2': 129.0},
#  {'Standard_NC_YCY_v1.0': 1208204054.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 100.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 100.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.0393812,
#   'real_loss_0': 0.0,
#   'real_delay_0': 100.0,
#   'real_tx_packets_0': 97.0,
#   'real_rx_packets_0': 97.0,
#   'real_bw_1': 0.0418618,
#   'real_loss_1': 0.0,
#   'real_delay_1': 110.0,
#   'real_tx_packets_1': 97.0,
#   'real_rx_packets_1': 97.0,
#   'real_bw_2': 0.0440955,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 96.0,
#   'real_rx_packets_2': 96.0},
#  {'Standard_NC_YCY_v1.0': 1208204058.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 30.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 35.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.005,
#   'set delay_2': 5.0,
#   'real_bw_0': 0.074452,
#   'real_loss_0': 0.0,
#   'real_delay_0': 31.0,
#   'real_tx_packets_0': 176.0,
#   'real_rx_packets_0': 176.0,
#   'real_bw_1': 0.0768734,
#   'real_loss_1': 0.0,
#   'real_delay_1': 35.0,
#   'real_tx_packets_1': 175.0,
#   'real_rx_packets_1': 175.0,
#   'real_bw_2': 0.0781543,
#   'real_loss_2': 0.0,
#   'real_delay_2': 5.0,
#   'real_tx_packets_2': 175.0,
#   'real_rx_packets_2': 173.0},
#  {'Standard_NC_YCY_v1.0': 1208204102.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 20.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 5.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0958778,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 223.0,
#   'real_rx_packets_0': 223.0,
#   'real_bw_1': 0.0983983,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 223.0,
#   'real_rx_packets_1': 223.0,
#   'real_bw_2': 0.0975085,
#   'real_loss_2': 0.0,
#   'real_delay_2': 11.0,
#   'real_tx_packets_2': 223.0,
#   'real_rx_packets_2': 223.0},
#  {'Standard_NC_YCY_v1.0': 1208204106.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 10.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.001,
#   'set delay_1': 30.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0892479,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 202.0,
#   'real_rx_packets_0': 202.0,
#   'real_bw_1': 0.0873355,
#   'real_loss_1': 0.0,
#   'real_delay_1': 31.0,
#   'real_tx_packets_1': 201.0,
#   'real_rx_packets_1': 200.0,
#   'real_bw_2': 0.0857263,
#   'real_loss_2': 0.0,
#   'real_delay_2': 100.0,
#   'real_tx_packets_2': 201.0,
#   'real_rx_packets_2': 200.0},
#  {'Standard_NC_YCY_v1.0': 1208204111.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 25.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 100.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0448994,
#   'real_loss_0': 0.0,
#   'real_delay_0': 25.0,
#   'real_tx_packets_0': 104.0,
#   'real_rx_packets_0': 104.0,
#   'real_bw_1': 0.0455939,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 104.0,
#   'real_rx_packets_1': 104.0,
#   'real_bw_2': 0.0458213,
#   'real_loss_2': 0.0,
#   'real_delay_2': 100.0,
#   'real_tx_packets_2': 104.0,
#   'real_rx_packets_2': 104.0},
#  {'Standard_NC_YCY_v1.0': 1208204115.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 10.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 10.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.142196,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 323.0,
#   'real_rx_packets_0': 322.0,
#   'real_bw_1': 0.141847,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 323.0,
#   'real_rx_packets_1': 323.0,
#   'real_bw_2': 0.142603,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 323.0,
#   'real_rx_packets_2': 323.0},
#  {'Standard_NC_YCY_v1.0': 1208204119.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 15.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.001,
#   'set delay_1': 20.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.001,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.094573,
#   'real_loss_0': 0.0,
#   'real_delay_0': 26.0,
#   'real_tx_packets_0': 208.0,
#   'real_rx_packets_0': 208.0,
#   'real_bw_1': 0.0946064,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 207.0,
#   'real_rx_packets_1': 207.0,
#   'real_bw_2': 0.0932803,
#   'real_loss_2': 0.0,
#   'real_delay_2': 25.0,
#   'real_tx_packets_2': 207.0,
#   'real_rx_packets_2': 207.0},
#  {'Standard_NC_YCY_v1.0': 1208204123.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 100.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 10.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0652285,
#   'real_loss_0': 0.0,
#   'real_delay_0': 100.0,
#   'real_tx_packets_0': 156.0,
#   'real_rx_packets_0': 155.0,
#   'real_bw_1': 0.0684066,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 155.0,
#   'real_rx_packets_1': 155.0,
#   'real_bw_2': 0.0696412,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 155.0,
#   'real_rx_packets_2': 155.0},
#  {'Standard_NC_YCY_v1.0': 1208204127.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 15.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 35.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.001,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.122636,
#   'real_loss_0': 0.0,
#   'real_delay_0': 16.0,
#   'real_tx_packets_0': 265.0,
#   'real_rx_packets_0': 265.0,
#   'real_bw_1': 0.123293,
#   'real_loss_1': 0.0,
#   'real_delay_1': 46.0,
#   'real_tx_packets_1': 264.0,
#   'real_rx_packets_1': 264.0,
#   'real_bw_2': 0.12432,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 264.0,
#   'real_rx_packets_2': 264.0},
#  {'Standard_NC_YCY_v1.0': 1208204132.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 35.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 25.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.005,
#   'set delay_2': 5.0,
#   'real_bw_0': 0.0964272,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 213.0,
#   'real_rx_packets_0': 213.0,
#   'real_bw_1': 0.0964375,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 212.0,
#   'real_rx_packets_1': 212.0,
#   'real_bw_2': 0.0957465,
#   'real_loss_2': 0.0,
#   'real_delay_2': 5.0,
#   'real_tx_packets_2': 212.0,
#   'real_rx_packets_2': 210.0},
#  {'Standard_NC_YCY_v1.0': 1208204136.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 35.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 100.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 5.0,
#   'real_bw_0': 0.0525124,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 120.0,
#   'real_rx_packets_0': 120.0,
#   'real_bw_1': 0.0518506,
#   'real_loss_1': 0.0,
#   'real_delay_1': 110.0,
#   'real_tx_packets_1': 119.0,
#   'real_rx_packets_1': 119.0,
#   'real_bw_2': 0.055019,
#   'real_loss_2': 0.0,
#   'real_delay_2': 5.0,
#   'real_tx_packets_2': 119.0,
#   'real_rx_packets_2': 119.0},
#  {'Standard_NC_YCY_v1.0': 1208204140.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 40.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 35.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.0998534,
#   'real_loss_0': 0.0,
#   'real_delay_0': 50.0,
#   'real_tx_packets_0': 232.0,
#   'real_rx_packets_0': 231.0,
#   'real_bw_1': 0.101983,
#   'real_loss_1': 0.0,
#   'real_delay_1': 36.0,
#   'real_tx_packets_1': 231.0,
#   'real_rx_packets_1': 231.0,
#   'real_bw_2': 0.101808,
#   'real_loss_2': 0.0,
#   'real_delay_2': 15.0,
#   'real_tx_packets_2': 231.0,
#   'real_rx_packets_2': 231.0},
#  {'Standard_NC_YCY_v1.0': 1208204144.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 20.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 10.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 5.0,
#   'real_bw_0': 0.0887099,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 206.0,
#   'real_rx_packets_0': 206.0,
#   'real_bw_1': 0.0891747,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 206.0,
#   'real_rx_packets_1': 206.0,
#   'real_bw_2': 0.0907786,
#   'real_loss_2': 0.0,
#   'real_delay_2': 6.0,
#   'real_tx_packets_2': 205.0,
#   'real_rx_packets_2': 205.0},
#  {'Standard_NC_YCY_v1.0': 1208204149.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 15.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 30.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.005,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.118332,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 254.0,
#   'real_rx_packets_0': 254.0,
#   'real_bw_1': 0.118254,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 254.0,
#   'real_rx_packets_1': 254.0,
#   'real_bw_2': 0.110478,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 254.0,
#   'real_rx_packets_2': 252.0},
#  {'Standard_NC_YCY_v1.0': 1208204153.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 15.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 20.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.005,
#   'set delay_2': 15.0,
#   'real_bw_0': 1.46384,
#   'real_loss_0': 0.0,
#   'real_delay_0': 17.0,
#   'real_tx_packets_0': 3132.0,
#   'real_rx_packets_0': 3130.0,
#   'real_bw_1': 1.54426,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 3131.0,
#   'real_rx_packets_1': 3131.0,
#   'real_bw_2': 1.54583,
#   'real_loss_2': 0.0,
#   'real_delay_2': 16.0,
#   'real_tx_packets_2': 3131.0,
#   'real_rx_packets_2': 3119.0},
#  {'Standard_NC_YCY_v1.0': 1208204204.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.001,
#   'set delay_0': 20.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.005,
#   'set delay_1': 30.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.001,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.405858,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 862.0,
#   'real_rx_packets_0': 861.0,
#   'real_bw_1': 0.406987,
#   'real_loss_1': 0.0,
#   'real_delay_1': 31.0,
#   'real_tx_packets_1': 861.0,
#   'real_rx_packets_1': 857.0,
#   'real_bw_2': 0.408247,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 861.0,
#   'real_rx_packets_2': 861.0},
#  {'Standard_NC_YCY_v1.0': 1208204209.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 40.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.005,
#   'set delay_1': 15.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0929202,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 210.0,
#   'real_rx_packets_0': 210.0,
#   'real_bw_1': 0.0933712,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 210.0,
#   'real_rx_packets_1': 208.0,
#   'real_bw_2': 0.096158,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 210.0,
#   'real_rx_packets_2': 210.0},
#  {'Standard_NC_YCY_v1.0': 1208204214.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 35.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.005,
#   'set delay_1': 35.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0831187,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 192.0,
#   'real_rx_packets_0': 191.0,
#   'real_bw_1': 0.0830418,
#   'real_loss_1': 0.0,
#   'real_delay_1': 35.0,
#   'real_tx_packets_1': 192.0,
#   'real_rx_packets_1': 189.0,
#   'real_bw_2': 0.0820431,
#   'real_loss_2': 0.0,
#   'real_delay_2': 111.0,
#   'real_tx_packets_2': 192.0,
#   'real_rx_packets_2': 190.0},
#  {'Standard_NC_YCY_v1.0': 1208204218.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.001,
#   'set delay_0': 30.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 5.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0513947,
#   'real_loss_0': 0.0,
#   'real_delay_0': 30.0,
#   'real_tx_packets_0': 118.0,
#   'real_rx_packets_0': 118.0,
#   'real_bw_1': 0.0506016,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 118.0,
#   'real_rx_packets_1': 118.0,
#   'real_bw_2': 0.0531678,
#   'real_loss_2': 0.0,
#   'real_delay_2': 100.0,
#   'real_tx_packets_2': 117.0,
#   'real_rx_packets_2': 117.0},
#  {'Standard_NC_YCY_v1.0': 1208204222.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 10.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.001,
#   'set delay_1': 20.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 10.0,
#   'real_bw_0': 3.24159,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 6912.0,
#   'real_rx_packets_0': 6907.0,
#   'real_bw_1': 3.23317,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 6912.0,
#   'real_rx_packets_1': 6910.0,
#   'real_bw_2': 3.24565,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 6912.0,
#   'real_rx_packets_2': 6908.0},
#  {'Standard_NC_YCY_v1.0': 1208204241.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.001,
#   'set delay_0': 30.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.005,
#   'set delay_1': 40.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.105193,
#   'real_loss_0': 0.0,
#   'real_delay_0': 30.0,
#   'real_tx_packets_0': 231.0,
#   'real_rx_packets_0': 231.0,
#   'real_bw_1': 0.104635,
#   'real_loss_1': 0.0,
#   'real_delay_1': 40.0,
#   'real_tx_packets_1': 231.0,
#   'real_rx_packets_1': 229.0,
#   'real_bw_2': 0.107108,
#   'real_loss_2': 0.0,
#   'real_delay_2': 16.0,
#   'real_tx_packets_2': 231.0,
#   'real_rx_packets_2': 231.0},
#  {'Standard_NC_YCY_v1.0': 1208204246.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 10.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.001,
#   'set delay_1': 100.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.0601964,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 135.0,
#   'real_rx_packets_0': 135.0,
#   'real_bw_1': 0.0570853,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 135.0,
#   'real_rx_packets_1': 135.0,
#   'real_bw_2': 0.0566138,
#   'real_loss_2': 0.0,
#   'real_delay_2': 26.0,
#   'real_tx_packets_2': 135.0,
#   'real_rx_packets_2': 135.0},
#  {'Standard_NC_YCY_v1.0': 1208204250.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 10.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 35.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0692775,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 154.0,
#   'real_rx_packets_0': 154.0,
#   'real_bw_1': 0.0704775,
#   'real_loss_1': 0.0,
#   'real_delay_1': 36.0,
#   'real_tx_packets_1': 154.0,
#   'real_rx_packets_1': 154.0,
#   'real_bw_2': 0.066908,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 153.0,
#   'real_rx_packets_2': 153.0},
#  {'Standard_NC_YCY_v1.0': 1208204254.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 25.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 30.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.103878,
#   'real_loss_0': 0.0,
#   'real_delay_0': 25.0,
#   'real_tx_packets_0': 236.0,
#   'real_rx_packets_0': 236.0,
#   'real_bw_1': 0.102994,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 235.0,
#   'real_rx_packets_1': 235.0,
#   'real_bw_2': 0.105673,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 235.0,
#   'real_rx_packets_2': 235.0},
#  {'Standard_NC_YCY_v1.0': 1208204258.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 35.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 100.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.005,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0679964,
#   'real_loss_0': 0.0,
#   'real_delay_0': 45.0,
#   'real_tx_packets_0': 155.0,
#   'real_rx_packets_0': 155.0,
#   'real_bw_1': 0.0690982,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 155.0,
#   'real_rx_packets_1': 155.0,
#   'real_bw_2': 0.0709485,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 154.0,
#   'real_rx_packets_2': 153.0},
#  {'Standard_NC_YCY_v1.0': 1208204302.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 40.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 20.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0901783,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 210.0,
#   'real_rx_packets_0': 210.0,
#   'real_bw_1': 0.0922236,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 210.0,
#   'real_rx_packets_1': 210.0,
#   'real_bw_2': 0.0927117,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 210.0,
#   'real_rx_packets_2': 210.0},
#  {'Standard_NC_YCY_v1.0': 1208204306.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 15.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 30.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.130563,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 302.0,
#   'real_rx_packets_0': 300.0,
#   'real_bw_1': 0.133376,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 302.0,
#   'real_rx_packets_1': 301.0,
#   'real_bw_2': 0.134091,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 302.0,
#   'real_rx_packets_2': 300.0},
#  {'Standard_NC_YCY_v1.0': 1208204311.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.005,
#   'set delay_0': 35.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 30.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.005,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0974093,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 217.0,
#   'real_rx_packets_0': 216.0,
#   'real_bw_1': 0.0978647,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 216.0,
#   'real_rx_packets_1': 216.0,
#   'real_bw_2': 0.0984666,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 216.0,
#   'real_rx_packets_2': 214.0},
#  {'Standard_NC_YCY_v1.0': 1208204315.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 15.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 35.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.109134,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 242.0,
#   'real_rx_packets_0': 242.0,
#   'real_bw_1': 0.111167,
#   'real_loss_1': 0.0,
#   'real_delay_1': 35.0,
#   'real_tx_packets_1': 242.0,
#   'real_rx_packets_1': 242.0,
#   'real_bw_2': 0.111189,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 241.0,
#   'real_rx_packets_2': 241.0},
#  {'Standard_NC_YCY_v1.0': 1208204319.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.001,
#   'set delay_0': 30.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 40.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.093583,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 214.0,
#   'real_rx_packets_0': 214.0,
#   'real_bw_1': 0.0932147,
#   'real_loss_1': 0.0,
#   'real_delay_1': 40.0,
#   'real_tx_packets_1': 214.0,
#   'real_rx_packets_1': 214.0,
#   'real_bw_2': 0.0942364,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 213.0,
#   'real_rx_packets_2': 213.0},
#  {'Standard_NC_YCY_v1.0': 1208204324.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 10.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 5.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0637064,
#   'real_loss_0': 0.0,
#   'real_delay_0': 19.0,
#   'real_tx_packets_0': 153.0,
#   'real_rx_packets_0': 152.0,
#   'real_bw_1': 0.0675783,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 152.0,
#   'real_rx_packets_1': 152.0,
#   'real_bw_2': 0.0643213,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 152.0,
#   'real_rx_packets_2': 151.0},
#  {'Standard_NC_YCY_v1.0': 1208204328.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 5.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 25.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0787046,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 179.0,
#   'real_rx_packets_0': 179.0,
#   'real_bw_1': 0.0761922,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 179.0,
#   'real_rx_packets_1': 179.0,
#   'real_bw_2': 0.0776985,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 179.0,
#   'real_rx_packets_2': 179.0},
#  {'Standard_NC_YCY_v1.0': 1208204332.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 5.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 30.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0737146,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 162.0,
#   'real_rx_packets_0': 162.0,
#   'real_bw_1': 0.0741524,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 162.0,
#   'real_rx_packets_1': 162.0,
#   'real_bw_2': 0.071585,
#   'real_loss_2': 0.0,
#   'real_delay_2': 100.0,
#   'real_tx_packets_2': 162.0,
#   'real_rx_packets_2': 162.0},
#  {'Standard_NC_YCY_v1.0': 1208204336.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.005,
#   'set delay_0': 15.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 10.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0635676,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 151.0,
#   'real_rx_packets_0': 150.0,
#   'real_bw_1': 0.0660801,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 151.0,
#   'real_rx_packets_1': 151.0,
#   'real_bw_2': 0.0641853,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 150.0,
#   'real_rx_packets_2': 150.0},
#  {'Standard_NC_YCY_v1.0': 1208204340.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.005,
#   'set delay_0': 40.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 30.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0488335,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 112.0,
#   'real_rx_packets_0': 111.0,
#   'real_bw_1': 0.0487188,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 111.0,
#   'real_rx_packets_1': 111.0,
#   'real_bw_2': 0.0501145,
#   'real_loss_2': 0.0,
#   'real_delay_2': 110.0,
#   'real_tx_packets_2': 111.0,
#   'real_rx_packets_2': 111.0},
#  {'Standard_NC_YCY_v1.0': 1208204344.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 10.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 30.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0786424,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 178.0,
#   'real_rx_packets_0': 178.0,
#   'real_bw_1': 0.0766823,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 178.0,
#   'real_rx_packets_1': 178.0,
#   'real_bw_2': 0.0762717,
#   'real_loss_2': 0.0,
#   'real_delay_2': 100.0,
#   'real_tx_packets_2': 178.0,
#   'real_rx_packets_2': 178.0},
#  {'Standard_NC_YCY_v1.0': 1208204348.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.005,
#   'set delay_0': 100.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 15.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.0768123,
#   'real_loss_0': 0.0,
#   'real_delay_0': 100.0,
#   'real_tx_packets_0': 179.0,
#   'real_rx_packets_0': 178.0,
#   'real_bw_1': 0.0792237,
#   'real_loss_1': 0.0,
#   'real_delay_1': 16.0,
#   'real_tx_packets_1': 179.0,
#   'real_rx_packets_1': 179.0,
#   'real_bw_2': 0.0775475,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 178.0,
#   'real_rx_packets_2': 178.0},
#  {'Standard_NC_YCY_v1.0': 1208204352.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 5.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.001,
#   'set delay_1': 15.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 5.0,
#   'real_bw_0': 2.98172,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 6370.0,
#   'real_rx_packets_0': 6366.0,
#   'real_bw_1': 2.98788,
#   'real_loss_1': 0.0,
#   'real_delay_1': 17.0,
#   'real_tx_packets_1': 6369.0,
#   'real_rx_packets_1': 6367.0,
#   'real_bw_2': 2.99431,
#   'real_loss_2': 0.0,
#   'real_delay_2': 5.0,
#   'real_tx_packets_2': 6369.0,
#   'real_rx_packets_2': 6368.0},
#  {'Standard_NC_YCY_v1.0': 1208204410.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.001,
#   'set delay_0': 20.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.001,
#   'set delay_1': 25.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.101169,
#   'real_loss_0': 0.0,
#   'real_delay_0': 31.0,
#   'real_tx_packets_0': 233.0,
#   'real_rx_packets_0': 233.0,
#   'real_bw_1': 0.10365,
#   'real_loss_1': 0.0,
#   'real_delay_1': 26.0,
#   'real_tx_packets_1': 232.0,
#   'real_rx_packets_1': 232.0,
#   'real_bw_2': 0.100777,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 232.0,
#   'real_rx_packets_2': 232.0},
#  {'Standard_NC_YCY_v1.0': 1208204414.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.001,
#   'set delay_0': 10.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.005,
#   'set delay_1': 5.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.122721,
#   'real_loss_0': 0.0,
#   'real_delay_0': 11.0,
#   'real_tx_packets_0': 266.0,
#   'real_rx_packets_0': 266.0,
#   'real_bw_1': 0.123103,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 266.0,
#   'real_rx_packets_1': 264.0,
#   'real_bw_2': 0.123154,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 265.0,
#   'real_rx_packets_2': 265.0},
#  {'Standard_NC_YCY_v1.0': 1208204418.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 20.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 25.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.001,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.114916,
#   'real_loss_0': 0.0,
#   'real_delay_0': 21.0,
#   'real_tx_packets_0': 243.0,
#   'real_rx_packets_0': 243.0,
#   'real_bw_1': 0.112274,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 243.0,
#   'real_rx_packets_1': 243.0,
#   'real_bw_2': 0.115926,
#   'real_loss_2': 0.0,
#   'real_delay_2': 15.0,
#   'real_tx_packets_2': 243.0,
#   'real_rx_packets_2': 243.0},
#  {'Standard_NC_YCY_v1.0': 1208204423.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 25.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 20.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.005,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.0700373,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 162.0,
#   'real_rx_packets_0': 162.0,
#   'real_bw_1': 0.0721479,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 162.0,
#   'real_rx_packets_1': 162.0,
#   'real_bw_2': 0.0683886,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 162.0,
#   'real_rx_packets_2': 160.0},
#  {'Standard_NC_YCY_v1.0': 1208204427.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 10.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 5.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.0630719,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 143.0,
#   'real_rx_packets_0': 143.0,
#   'real_bw_1': 0.0660826,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 143.0,
#   'real_rx_packets_1': 143.0,
#   'real_bw_2': 0.0632672,
#   'real_loss_2': 0.0,
#   'real_delay_2': 25.0,
#   'real_tx_packets_2': 143.0,
#   'real_rx_packets_2': 143.0},
#  {'Standard_NC_YCY_v1.0': 1208204431.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 5.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 20.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0769092,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 177.0,
#   'real_rx_packets_0': 177.0,
#   'real_bw_1': 0.0764682,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 177.0,
#   'real_rx_packets_1': 177.0,
#   'real_bw_2': 0.0761384,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 176.0,
#   'real_rx_packets_2': 176.0},
#  {'Standard_NC_YCY_v1.0': 1208204435.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.005,
#   'set delay_0': 15.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 15.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.005,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.100394,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 227.0,
#   'real_rx_packets_0': 226.0,
#   'real_bw_1': 0.0975292,
#   'real_loss_1': 0.0,
#   'real_delay_1': 26.0,
#   'real_tx_packets_1': 227.0,
#   'real_rx_packets_1': 227.0,
#   'real_bw_2': 0.0985972,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 227.0,
#   'real_rx_packets_2': 225.0},
#  {'Standard_NC_YCY_v1.0': 1208204439.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 30.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 15.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.001,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.078383,
#   'real_loss_0': 0.0,
#   'real_delay_0': 30.0,
#   'real_tx_packets_0': 179.0,
#   'real_rx_packets_0': 179.0,
#   'real_bw_1': 0.0776162,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 179.0,
#   'real_rx_packets_1': 179.0,
#   'real_bw_2': 0.0784762,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 179.0,
#   'real_rx_packets_2': 179.0},
#  {'Standard_NC_YCY_v1.0': 1208204444.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 35.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.005,
#   'set delay_1': 20.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.113237,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 261.0,
#   'real_rx_packets_0': 260.0,
#   'real_bw_1': 0.113614,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 260.0,
#   'real_rx_packets_1': 257.0,
#   'real_bw_2': 0.11442,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 260.0,
#   'real_rx_packets_2': 259.0},
#  {'Standard_NC_YCY_v1.0': 1208204448.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 100.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 35.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0651192,
#   'real_loss_0': 0.0,
#   'real_delay_0': 100.0,
#   'real_tx_packets_0': 153.0,
#   'real_rx_packets_0': 152.0,
#   'real_bw_1': 0.0647463,
#   'real_loss_1': 0.0,
#   'real_delay_1': 36.0,
#   'real_tx_packets_1': 152.0,
#   'real_rx_packets_1': 152.0,
#   'real_bw_2': 0.0667965,
#   'real_loss_2': 0.0,
#   'real_delay_2': 21.0,
#   'real_tx_packets_2': 152.0,
#   'real_rx_packets_2': 152.0},
#  {'Standard_NC_YCY_v1.0': 1208204452.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 20.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.001,
#   'set delay_1': 10.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0760897,
#   'real_loss_0': 0.0,
#   'real_delay_0': 21.0,
#   'real_tx_packets_0': 170.0,
#   'real_rx_packets_0': 170.0,
#   'real_bw_1': 0.0778521,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 170.0,
#   'real_rx_packets_1': 170.0,
#   'real_bw_2': 0.0774151,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 170.0,
#   'real_rx_packets_2': 170.0},
#  {'Standard_NC_YCY_v1.0': 1208204456.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 15.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.001,
#   'set delay_1': 5.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0678978,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 158.0,
#   'real_rx_packets_0': 158.0,
#   'real_bw_1': 0.0708614,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 158.0,
#   'real_rx_packets_1': 158.0,
#   'real_bw_2': 0.0702166,
#   'real_loss_2': 0.0,
#   'real_delay_2': 31.0,
#   'real_tx_packets_2': 158.0,
#   'real_rx_packets_2': 158.0},
#  {'Standard_NC_YCY_v1.0': 1208204500.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 5.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.005,
#   'set delay_1': 15.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.0816664,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 182.0,
#   'real_rx_packets_0': 182.0,
#   'real_bw_1': 0.0832489,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 182.0,
#   'real_rx_packets_1': 180.0,
#   'real_bw_2': 0.0808663,
#   'real_loss_2': 0.0,
#   'real_delay_2': 51.0,
#   'real_tx_packets_2': 181.0,
#   'real_rx_packets_2': 181.0},
#  {'Standard_NC_YCY_v1.0': 1208204504.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 20.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 15.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.06289,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 144.0,
#   'real_rx_packets_0': 144.0,
#   'real_bw_1': 0.0619038,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 143.0,
#   'real_rx_packets_1': 143.0,
#   'real_bw_2': 0.0598358,
#   'real_loss_2': 0.0,
#   'real_delay_2': 25.0,
#   'real_tx_packets_2': 143.0,
#   'real_rx_packets_2': 143.0},
#  {'Standard_NC_YCY_v1.0': 1208204509.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 40.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.001,
#   'set delay_1': 100.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.0686088,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 159.0,
#   'real_rx_packets_0': 159.0,
#   'real_bw_1': 0.0680081,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 159.0,
#   'real_rx_packets_1': 159.0,
#   'real_bw_2': 0.0702501,
#   'real_loss_2': 0.0,
#   'real_delay_2': 46.0,
#   'real_tx_packets_2': 159.0,
#   'real_rx_packets_2': 159.0},
#  {'Standard_NC_YCY_v1.0': 1208204513.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 40.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 100.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0577707,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 132.0,
#   'real_rx_packets_0': 132.0,
#   'real_bw_1': 0.0542659,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 132.0,
#   'real_rx_packets_1': 131.0,
#   'real_bw_2': 0.0564892,
#   'real_loss_2': 0.0,
#   'real_delay_2': 41.0,
#   'real_tx_packets_2': 132.0,
#   'real_rx_packets_2': 132.0},
#  {'Standard_NC_YCY_v1.0': 1208204517.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 5.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 100.0,
#   'set bw_2': 90.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0552189,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 133.0,
#   'real_rx_packets_0': 133.0,
#   'real_bw_1': 0.0570217,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 133.0,
#   'real_rx_packets_1': 132.0,
#   'real_bw_2': 0.0586478,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 132.0,
#   'real_rx_packets_2': 132.0},
#  {'Standard_NC_YCY_v1.0': 1208204521.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 10.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 30.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.56759,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 1172.0,
#   'real_rx_packets_0': 1171.0,
#   'real_bw_1': 0.545747,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 1172.0,
#   'real_rx_packets_1': 1172.0,
#   'real_bw_2': 0.547916,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 1172.0,
#   'real_rx_packets_2': 1172.0},
#  {'Standard_NC_YCY_v1.0': 1208204527.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 40.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 15.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.111579,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 257.0,
#   'real_rx_packets_0': 255.0,
#   'real_bw_1': 0.112799,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 256.0,
#   'real_rx_packets_1': 256.0,
#   'real_bw_2': 0.111771,
#   'real_loss_2': 0.0,
#   'real_delay_2': 26.0,
#   'real_tx_packets_2': 256.0,
#   'real_rx_packets_2': 255.0},
#  {'Standard_NC_YCY_v1.0': 1208204531.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 35.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.005,
#   'set delay_1': 35.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.109009,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 231.0,
#   'real_rx_packets_0': 231.0,
#   'real_bw_1': 0.106322,
#   'real_loss_1': 0.0,
#   'real_delay_1': 35.0,
#   'real_tx_packets_1': 231.0,
#   'real_rx_packets_1': 229.0,
#   'real_bw_2': 0.106771,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 231.0,
#   'real_rx_packets_2': 231.0},
#  {'Standard_NC_YCY_v1.0': 1208204536.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 20.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 25.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0822056,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 190.0,
#   'real_rx_packets_0': 190.0,
#   'real_bw_1': 0.0821386,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 190.0,
#   'real_rx_packets_1': 189.0,
#   'real_bw_2': 0.0821559,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 189.0,
#   'real_rx_packets_2': 189.0},
#  {'Standard_NC_YCY_v1.0': 1208204540.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.001,
#   'set delay_0': 20.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 100.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.001,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.0753698,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 173.0,
#   'real_rx_packets_0': 173.0,
#   'real_bw_1': 0.0784403,
#   'real_loss_1': 0.0,
#   'real_delay_1': 101.0,
#   'real_tx_packets_1': 173.0,
#   'real_rx_packets_1': 172.0,
#   'real_bw_2': 0.0794678,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 172.0,
#   'real_rx_packets_2': 172.0},
#  {'Standard_NC_YCY_v1.0': 1208204544.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 35.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 10.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.0620949,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 144.0,
#   'real_rx_packets_0': 144.0,
#   'real_bw_1': 0.0619529,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 143.0,
#   'real_rx_packets_1': 143.0,
#   'real_bw_2': 0.0608318,
#   'real_loss_2': 0.0,
#   'real_delay_2': 15.0,
#   'real_tx_packets_2': 143.0,
#   'real_rx_packets_2': 143.0},
#  {'Standard_NC_YCY_v1.0': 1208204548.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 15.0,
#   'set bw_1': 20.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 30.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0647917,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 152.0,
#   'real_rx_packets_0': 152.0,
#   'real_bw_1': 0.0660767,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 151.0,
#   'real_rx_packets_1': 151.0,
#   'real_bw_2': 0.0676707,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 151.0,
#   'real_rx_packets_2': 151.0},
#  {'Standard_NC_YCY_v1.0': 1208204552.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 5.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 40.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.125081,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 289.0,
#   'real_rx_packets_0': 288.0,
#   'real_bw_1': 0.127448,
#   'real_loss_1': 0.0,
#   'real_delay_1': 40.0,
#   'real_tx_packets_1': 289.0,
#   'real_rx_packets_1': 288.0,
#   'real_bw_2': 0.127563,
#   'real_loss_2': 0.0,
#   'real_delay_2': 21.0,
#   'real_tx_packets_2': 288.0,
#   'real_rx_packets_2': 288.0},
#  {'Standard_NC_YCY_v1.0': 1208204556.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.001,
#   'set delay_0': 35.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 10.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.0957484,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 210.0,
#   'real_rx_packets_0': 210.0,
#   'real_bw_1': 0.096732,
#   'real_loss_1': 0.0,
#   'real_delay_1': 10.0,
#   'real_tx_packets_1': 210.0,
#   'real_rx_packets_1': 210.0,
#   'real_bw_2': 0.0967358,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 209.0,
#   'real_rx_packets_2': 209.0},
#  {'Standard_NC_YCY_v1.0': 1208204601.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 35.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.001,
#   'set delay_1': 10.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0904574,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 203.0,
#   'real_rx_packets_0': 203.0,
#   'real_bw_1': 0.0859942,
#   'real_loss_1': 0.0,
#   'real_delay_1': 20.0,
#   'real_tx_packets_1': 203.0,
#   'real_rx_packets_1': 203.0,
#   'real_bw_2': 0.0906848,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 203.0,
#   'real_rx_packets_2': 203.0},
#  {'Standard_NC_YCY_v1.0': 1208204605.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 40.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 15.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.005,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.505801,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 1067.0,
#   'real_rx_packets_0': 1066.0,
#   'real_bw_1': 0.507337,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 1067.0,
#   'real_rx_packets_1': 1067.0,
#   'real_bw_2': 0.505965,
#   'real_loss_2': 0.0,
#   'real_delay_2': 15.0,
#   'real_tx_packets_2': 1067.0,
#   'real_rx_packets_2': 1062.0},
#  {'Standard_NC_YCY_v1.0': 1208204611.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 25.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.001,
#   'set delay_1': 30.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.119071,
#   'real_loss_0': 0.0,
#   'real_delay_0': 25.0,
#   'real_tx_packets_0': 271.0,
#   'real_rx_packets_0': 271.0,
#   'real_bw_1': 0.119451,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 271.0,
#   'real_rx_packets_1': 271.0,
#   'real_bw_2': 0.118807,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 270.0,
#   'real_rx_packets_2': 270.0},
#  {'Standard_NC_YCY_v1.0': 1208204615.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 10.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 15.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.001,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.064885,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 151.0,
#   'real_rx_packets_0': 151.0,
#   'real_bw_1': 0.0648694,
#   'real_loss_1': 0.0,
#   'real_delay_1': 15.0,
#   'real_tx_packets_1': 151.0,
#   'real_rx_packets_1': 151.0,
#   'real_bw_2': 0.0646389,
#   'real_loss_2': 0.0,
#   'real_delay_2': 110.0,
#   'real_tx_packets_2': 151.0,
#   'real_rx_packets_2': 150.0},
#  {'Standard_NC_YCY_v1.0': 1208204619.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 100.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 25.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.0679679,
#   'real_loss_0': 0.0,
#   'real_delay_0': 100.0,
#   'real_tx_packets_0': 161.0,
#   'real_rx_packets_0': 161.0,
#   'real_bw_1': 0.0706625,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 161.0,
#   'real_rx_packets_1': 161.0,
#   'real_bw_2': 0.0698128,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 160.0,
#   'real_rx_packets_2': 160.0},
#  {'Standard_NC_YCY_v1.0': 1208204623.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0004,
#   'set delay_0': 35.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 35.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.122315,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 278.0,
#   'real_rx_packets_0': 276.0,
#   'real_bw_1': 0.122322,
#   'real_loss_1': 0.0,
#   'real_delay_1': 35.0,
#   'real_tx_packets_1': 277.0,
#   'real_rx_packets_1': 276.0,
#   'real_bw_2': 0.120557,
#   'real_loss_2': 0.0,
#   'real_delay_2': 37.0,
#   'real_tx_packets_2': 277.0,
#   'real_rx_packets_2': 276.0},
#  {'Standard_NC_YCY_v1.0': 1208204627.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 20.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.001,
#   'set delay_1': 25.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.125164,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 274.0,
#   'real_rx_packets_0': 274.0,
#   'real_bw_1': 0.125994,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 274.0,
#   'real_rx_packets_1': 274.0,
#   'real_bw_2': 0.125274,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 274.0,
#   'real_rx_packets_2': 274.0},
#  {'Standard_NC_YCY_v1.0': 1208204632.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 5.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.001,
#   'set delay_1': 5.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 35.0,
#   'real_bw_0': 3.62944,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 7738.0,
#   'real_rx_packets_0': 7728.0,
#   'real_bw_1': 3.8189,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 7737.0,
#   'real_rx_packets_1': 7735.0,
#   'real_bw_2': 3.63967,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 7737.0,
#   'real_rx_packets_2': 7735.0},
#  {'Standard_NC_YCY_v1.0': 1208204651.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 20.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.005,
#   'set delay_1': 20.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.126133,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 285.0,
#   'real_rx_packets_0': 285.0,
#   'real_bw_1': 0.123129,
#   'real_loss_1': 0.0,
#   'real_delay_1': 31.0,
#   'real_tx_packets_1': 285.0,
#   'real_rx_packets_1': 283.0,
#   'real_bw_2': 0.126374,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 284.0,
#   'real_rx_packets_2': 284.0},
#  {'Standard_NC_YCY_v1.0': 1208204656.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 10.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 5.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.001,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.139314,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 323.0,
#   'real_rx_packets_0': 321.0,
#   'real_bw_1': 0.143955,
#   'real_loss_1': 0.0,
#   'real_delay_1': 6.0,
#   'real_tx_packets_1': 323.0,
#   'real_rx_packets_1': 322.0,
#   'real_bw_2': 0.141956,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 322.0,
#   'real_rx_packets_2': 321.0},
#  {'Standard_NC_YCY_v1.0': 1208204700.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 40.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 30.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 30.0,
#   'real_bw_0': 0.105029,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 230.0,
#   'real_rx_packets_0': 230.0,
#   'real_bw_1': 0.105883,
#   'real_loss_1': 0.0,
#   'real_delay_1': 41.0,
#   'real_tx_packets_1': 230.0,
#   'real_rx_packets_1': 230.0,
#   'real_bw_2': 0.104016,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 230.0,
#   'real_rx_packets_2': 230.0},
#  {'Standard_NC_YCY_v1.0': 1208204705.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 20.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.001,
#   'set delay_1': 30.0,
#   'set bw_2': 20.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.122653,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 270.0,
#   'real_rx_packets_0': 270.0,
#   'real_bw_1': 0.124262,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 269.0,
#   'real_rx_packets_1': 269.0,
#   'real_bw_2': 0.123588,
#   'real_loss_2': 0.0,
#   'real_delay_2': 25.0,
#   'real_tx_packets_2': 269.0,
#   'real_rx_packets_2': 269.0},
#  {'Standard_NC_YCY_v1.0': 1208204709.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 20.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 30.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.005,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.123737,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 270.0,
#   'real_rx_packets_0': 270.0,
#   'real_bw_1': 0.124114,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 270.0,
#   'real_rx_packets_1': 270.0,
#   'real_bw_2': 0.123248,
#   'real_loss_2': 0.0,
#   'real_delay_2': 36.0,
#   'real_tx_packets_2': 269.0,
#   'real_rx_packets_2': 267.0},
#  {'Standard_NC_YCY_v1.0': 1208204713.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 20.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0008,
#   'set delay_1': 100.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.0008,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.079793,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 187.0,
#   'real_rx_packets_0': 187.0,
#   'real_bw_1': 0.0815405,
#   'real_loss_1': 0.0,
#   'real_delay_1': 101.0,
#   'real_tx_packets_1': 187.0,
#   'real_rx_packets_1': 187.0,
#   'real_bw_2': 0.08259,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 187.0,
#   'real_rx_packets_2': 186.0},
#  {'Standard_NC_YCY_v1.0': 1208204717.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 5.0,
#   'set bw_1': 90.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 30.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.073976,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 164.0,
#   'real_rx_packets_0': 164.0,
#   'real_bw_1': 0.0738537,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 163.0,
#   'real_rx_packets_1': 163.0,
#   'real_bw_2': 0.0733448,
#   'real_loss_2': 0.0,
#   'real_delay_2': 112.0,
#   'real_tx_packets_2': 163.0,
#   'real_rx_packets_2': 163.0},
#  {'Standard_NC_YCY_v1.0': 1208204722.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.001,
#   'set delay_0': 10.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 10.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.148118,
#   'real_loss_0': 0.0,
#   'real_delay_0': 11.0,
#   'real_tx_packets_0': 333.0,
#   'real_rx_packets_0': 332.0,
#   'real_bw_1': 0.147246,
#   'real_loss_1': 0.0,
#   'real_delay_1': 21.0,
#   'real_tx_packets_1': 332.0,
#   'real_rx_packets_1': 332.0,
#   'real_bw_2': 0.14441,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 332.0,
#   'real_rx_packets_2': 332.0},
#  {'Standard_NC_YCY_v1.0': 1208204726.0,
#   'set bw_0': 50.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 20.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.005,
#   'set delay_1': 20.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0002,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0700612,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 155.0,
#   'real_rx_packets_0': 155.0,
#   'real_bw_1': 0.069125,
#   'real_loss_1': 0.0,
#   'real_delay_1': 21.0,
#   'real_tx_packets_1': 155.0,
#   'real_rx_packets_1': 153.0,
#   'real_bw_2': 0.0687709,
#   'real_loss_2': 0.0,
#   'real_delay_2': 110.0,
#   'real_tx_packets_2': 154.0,
#   'real_rx_packets_2': 154.0},
#  {'Standard_NC_YCY_v1.0': 1208204730.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.001,
#   'set delay_0': 25.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 35.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.005,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0947694,
#   'real_loss_0': 0.0,
#   'real_delay_0': 35.0,
#   'real_tx_packets_0': 213.0,
#   'real_rx_packets_0': 213.0,
#   'real_bw_1': 0.0968101,
#   'real_loss_1': 0.0,
#   'real_delay_1': 45.0,
#   'real_tx_packets_1': 212.0,
#   'real_rx_packets_1': 212.0,
#   'real_bw_2': 0.096964,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 212.0,
#   'real_rx_packets_2': 210.0},
#  {'Standard_NC_YCY_v1.0': 1208204734.0,
#   'set bw_0': 80.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 25.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.0002,
#   'set delay_1': 30.0,
#   'set bw_2': 100.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.102337,
#   'real_loss_0': 0.0,
#   'real_delay_0': 25.0,
#   'real_tx_packets_0': 237.0,
#   'real_rx_packets_0': 237.0,
#   'real_bw_1': 0.104354,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 237.0,
#   'real_rx_packets_1': 237.0,
#   'real_bw_2': 0.104593,
#   'real_loss_2': 0.0,
#   'real_delay_2': 40.0,
#   'real_tx_packets_2': 236.0,
#   'real_rx_packets_2': 236.0},
#  {'Standard_NC_YCY_v1.0': 1208204738.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 40.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.005,
#   'set delay_1': 5.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.102488,
#   'real_loss_0': 0.0,
#   'real_delay_0': 51.0,
#   'real_tx_packets_0': 222.0,
#   'real_rx_packets_0': 222.0,
#   'real_bw_1': 0.100028,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 222.0,
#   'real_rx_packets_1': 220.0,
#   'real_bw_2': 0.096171,
#   'real_loss_2': 0.0,
#   'real_delay_2': 30.0,
#   'real_tx_packets_2': 222.0,
#   'real_rx_packets_2': 222.0},
#  {'Standard_NC_YCY_v1.0': 1208204743.0,
#   'set bw_0': 10.0,
#   'set loss_0': 0.001,
#   'set delay_0': 30.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 40.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.005,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.0828765,
#   'real_loss_0': 0.0,
#   'real_delay_0': 31.0,
#   'real_tx_packets_0': 192.0,
#   'real_rx_packets_0': 192.0,
#   'real_bw_1': 0.082774,
#   'real_loss_1': 0.0,
#   'real_delay_1': 50.0,
#   'real_tx_packets_1': 191.0,
#   'real_rx_packets_1': 191.0,
#   'real_bw_2': 0.0832541,
#   'real_loss_2': 0.0,
#   'real_delay_2': 15.0,
#   'real_tx_packets_2': 191.0,
#   'real_rx_packets_2': 189.0},
#  {'Standard_NC_YCY_v1.0': 1208204747.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 40.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.001,
#   'set delay_1': 15.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.076654,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 181.0,
#   'real_rx_packets_0': 181.0,
#   'real_bw_1': 0.0791752,
#   'real_loss_1': 0.0,
#   'real_delay_1': 26.0,
#   'real_tx_packets_1': 180.0,
#   'real_rx_packets_1': 180.0,
#   'real_bw_2': 0.079621,
#   'real_loss_2': 0.0,
#   'real_delay_2': 41.0,
#   'real_tx_packets_2': 180.0,
#   'real_rx_packets_2': 180.0},
#  {'Standard_NC_YCY_v1.0': 1208204751.0,
#   'set bw_0': 70.0,
#   'set loss_0': 0.0008,
#   'set delay_0': 20.0,
#   'set bw_1': 80.0,
#   'set loss_1': 0.005,
#   'set delay_1': 25.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.114391,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 262.0,
#   'real_rx_packets_0': 262.0,
#   'real_bw_1': 0.113775,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 262.0,
#   'real_rx_packets_1': 260.0,
#   'real_bw_2': 0.116056,
#   'real_loss_2': 0.0,
#   'real_delay_2': 16.0,
#   'real_tx_packets_2': 262.0,
#   'real_rx_packets_2': 262.0},
#  {'Standard_NC_YCY_v1.0': 1208204755.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 20.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0004,
#   'set delay_1': 10.0,
#   'set bw_2': 50.0,
#   'set loss_2': 0.0001,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.105335,
#   'real_loss_0': 0.0,
#   'real_delay_0': 20.0,
#   'real_tx_packets_0': 228.0,
#   'real_rx_packets_0': 228.0,
#   'real_bw_1': 0.105192,
#   'real_loss_1': 0.0,
#   'real_delay_1': 11.0,
#   'real_tx_packets_1': 228.0,
#   'real_rx_packets_1': 228.0,
#   'real_bw_2': 0.102141,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 228.0,
#   'real_rx_packets_2': 228.0},
#  {'Standard_NC_YCY_v1.0': 1208204800.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.001,
#   'set delay_0': 25.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 35.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.001,
#   'set delay_2': 35.0,
#   'real_bw_0': 0.141464,
#   'real_loss_0': 0.0,
#   'real_delay_0': 37.0,
#   'real_tx_packets_0': 326.0,
#   'real_rx_packets_0': 325.0,
#   'real_bw_1': 0.143919,
#   'real_loss_1': 0.0,
#   'real_delay_1': 36.0,
#   'real_tx_packets_1': 326.0,
#   'real_rx_packets_1': 325.0,
#   'real_bw_2': 0.145896,
#   'real_loss_2': 0.0,
#   'real_delay_2': 35.0,
#   'real_tx_packets_2': 325.0,
#   'real_rx_packets_2': 325.0},
#  {'Standard_NC_YCY_v1.0': 1208204804.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.001,
#   'set delay_0': 40.0,
#   'set bw_1': 1.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 5.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 100.0,
#   'real_bw_0': 0.0650576,
#   'real_loss_0': 0.0,
#   'real_delay_0': 40.0,
#   'real_tx_packets_0': 144.0,
#   'real_rx_packets_0': 144.0,
#   'real_bw_1': 0.0647786,
#   'real_loss_1': 0.0,
#   'real_delay_1': 16.0,
#   'real_tx_packets_1': 143.0,
#   'real_rx_packets_1': 143.0,
#   'real_bw_2': 0.062801,
#   'real_loss_2': 0.0,
#   'real_delay_2': 100.0,
#   'real_tx_packets_2': 143.0,
#   'real_rx_packets_2': 143.0},
#  {'Standard_NC_YCY_v1.0': 1208204808.0,
#   'set bw_0': 100.0,
#   'set loss_0': 0.005,
#   'set delay_0': 5.0,
#   'set bw_1': 10.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 35.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 15.0,
#   'real_bw_0': 0.0826943,
#   'real_loss_0': 0.0,
#   'real_delay_0': 5.0,
#   'real_tx_packets_0': 189.0,
#   'real_rx_packets_0': 188.0,
#   'real_bw_1': 0.0821738,
#   'real_loss_1': 0.0,
#   'real_delay_1': 36.0,
#   'real_tx_packets_1': 188.0,
#   'real_rx_packets_1': 188.0,
#   'real_bw_2': 0.0820879,
#   'real_loss_2': 0.0,
#   'real_delay_2': 15.0,
#   'real_tx_packets_2': 188.0,
#   'real_rx_packets_2': 188.0},
#  {'Standard_NC_YCY_v1.0': 1208204812.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0001,
#   'set delay_0': 15.0,
#   'set bw_1': 40.0,
#   'set loss_1': 0.001,
#   'set delay_1': 35.0,
#   'set bw_2': 80.0,
#   'set loss_2': 0.0004,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0832127,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 195.0,
#   'real_rx_packets_0': 195.0,
#   'real_bw_1': 0.0856026,
#   'real_loss_1': 0.0,
#   'real_delay_1': 35.0,
#   'real_tx_packets_1': 195.0,
#   'real_rx_packets_1': 195.0,
#   'real_bw_2': 0.0872961,
#   'real_loss_2': 0.0,
#   'real_delay_2': 10.0,
#   'real_tx_packets_2': 195.0,
#   'real_rx_packets_2': 195.0},
#  {'Standard_NC_YCY_v1.0': 1208204816.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.0002,
#   'set delay_0': 40.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0007,
#   'set delay_1': 5.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0007,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0576427,
#   'real_loss_0': 0.0,
#   'real_delay_0': 50.0,
#   'real_tx_packets_0': 135.0,
#   'real_rx_packets_0': 134.0,
#   'real_bw_1': 0.0592189,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 135.0,
#   'real_rx_packets_1': 135.0,
#   'real_bw_2': 0.055395,
#   'real_loss_2': 0.0,
#   'real_delay_2': 19.0,
#   'real_tx_packets_2': 134.0,
#   'real_rx_packets_2': 134.0},
#  {'Standard_NC_YCY_v1.0': 1208204820.0,
#   'set bw_0': 1.0,
#   'set loss_0': 0.005,
#   'set delay_0': 30.0,
#   'set bw_1': 70.0,
#   'set loss_1': 0.0001,
#   'set delay_1': 30.0,
#   'set bw_2': 70.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 25.0,
#   'real_bw_0': 0.0780413,
#   'real_loss_0': 0.0,
#   'real_delay_0': 41.0,
#   'real_tx_packets_0': 181.0,
#   'real_rx_packets_0': 179.0,
#   'real_bw_1': 0.0787867,
#   'real_loss_1': 0.0,
#   'real_delay_1': 30.0,
#   'real_tx_packets_1': 180.0,
#   'real_rx_packets_1': 179.0,
#   'real_bw_2': 0.0779825,
#   'real_loss_2': 0.0,
#   'real_delay_2': 25.0,
#   'real_tx_packets_2': 180.0,
#   'real_rx_packets_2': 179.0},
#  {'Standard_NC_YCY_v1.0': 1208204825.0,
#   'set bw_0': 40.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 10.0,
#   'set bw_1': 50.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 100.0,
#   'set bw_2': 40.0,
#   'set loss_2': 0.001,
#   'set delay_2': 20.0,
#   'real_bw_0': 0.0556635,
#   'real_loss_0': 0.0,
#   'real_delay_0': 10.0,
#   'real_tx_packets_0': 130.0,
#   'real_rx_packets_0': 130.0,
#   'real_bw_1': 0.0535937,
#   'real_loss_1': 0.0,
#   'real_delay_1': 100.0,
#   'real_tx_packets_1': 130.0,
#   'real_rx_packets_1': 130.0,
#   'real_bw_2': 0.0572623,
#   'real_loss_2': 0.0,
#   'real_delay_2': 20.0,
#   'real_tx_packets_2': 130.0,
#   'real_rx_packets_2': 130.0},
#  {'Standard_NC_YCY_v1.0': 1208204829.0,
#   'set bw_0': 20.0,
#   'set loss_0': 0.0005,
#   'set delay_0': 15.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.001,
#   'set delay_1': 5.0,
#   'set bw_2': 10.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 40.0,
#   'real_bw_0': 0.0711413,
#   'real_loss_0': 0.0,
#   'real_delay_0': 15.0,
#   'real_tx_packets_0': 167.0,
#   'real_rx_packets_0': 167.0,
#   'real_bw_1': 0.072813,
#   'real_loss_1': 0.0,
#   'real_delay_1': 5.0,
#   'real_tx_packets_1': 167.0,
#   'real_rx_packets_1': 167.0,
#   'real_bw_2': 0.0717067,
#   'real_loss_2': 0.0,
#   'real_delay_2': 41.0,
#   'real_tx_packets_2': 166.0,
#   'real_rx_packets_2': 166.0},
#  {'Standard_NC_YCY_v1.0': 1208204833.0,
#   'set bw_0': 90.0,
#   'set loss_0': 0.0007,
#   'set delay_0': 100.0,
#   'set bw_1': 100.0,
#   'set loss_1': 0.0005,
#   'set delay_1': 25.0,
#   'set bw_2': 1.0,
#   'set loss_2': 0.0005,
#   'set delay_2': 10.0,
#   'real_bw_0': 0.0772841,
#   'real_loss_0': 0.0,
#   'real_delay_0': 100.0,
#   'real_tx_packets_0': 179.0,
#   'real_rx_packets_0': 179.0,
#   'real_bw_1': 0.0775478,
#   'real_loss_1': 0.0,
#   'real_delay_1': 25.0,
#   'real_tx_packets_1': 179.0,
#   'real_rx_packets_1': 179.0,
#   'real_bw_2': 0.0784949,
#   'real_loss_2': 0.0,
#   'real_delay_2': 21.0,
#   'real_tx_packets_2': 179.0,
#   'real_rx_packets_2': 179.0}]

# %%
proc_bw_content_0=[]
proc_bw_content_1=[]
proc_bw_content_2=[]
proc_bw_content_sum=[]

# %%
pickup(proc_bw_content_0,proc_bw_content_1,proc_bw_content_2,content)
smooth(proc_bw_content_0)
smooth(proc_bw_content_1)
smooth(proc_bw_content_2)
mysum(proc_bw_content_0,proc_bw_content_1,proc_bw_content_2,proc_bw_content_sum)

# %%
plt.plot(proc_bw_content_0,'b',label="Link 1")
plt.plot(proc_bw_content_1,'r',label="Link 2",)
plt.plot(proc_bw_content_2,'g',label="Link 3")
#plt.plot(proc_bw_content_sum,linestyle='-',color='mediumvioletred',label="Total",linewidth=2)
plt.xlabel("Simulation time(20s)",fontsize=11)
plt.ylabel("Throughput(Mbps)",fontsize=11)
plt.legend(fontsize=11)
#plt.legend(bbox_to_anchor=(1.05,0.75),loc=3,borderaxespad=0)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.show()

# %%
proc_bw_content_sum
# Out:
# [0.2981436,
#  0.163688,
#  0.1654283,
#  0.1253385,
#  0.2294797,
#  0.2917846,
#  0.2623097,
#  0.1363146,
#  0.42664599999999997,
#  0.2824597,
#  0.20327630000000002,
#  0.370249,
#  0.2886112,
#  0.159382,
#  0.3036444,
#  0.2686632,
#  0.34706400000000004,
#  4.553929999999999,
#  1.221092,
#  0.28244939999999996,
#  0.24820359999999997,
#  0.1551641,
#  9.72041,
#  0.316936,
#  0.17389549999999998,
#  0.206663,
#  0.312545,
#  0.2080431,
#  0.2751136,
#  0.39803,
#  0.2937406,
#  0.33149,
#  0.2810341,
#  0.19560599999999997,
#  0.2325953,
#  0.21945199999999998,
#  0.193833,
#  0.14766680000000001,
#  0.23159639999999998,
#  0.2335835,
#  8.96391,
#  0.305596,
#  0.368978,
#  0.343116,
#  0.2105738,
#  0.1924217,
#  0.2295158,
#  0.2965204,
#  0.2344754,
#  0.341271,
#  0.196662,
#  0.23135689999999998,
#  0.2089758,
#  0.2457816,
#  0.1846296,
#  0.20686699999999997,
#  0.1685258,
#  0.1708884,
#  1.6612529999999999,
#  0.336149,
#  0.322102,
#  0.2465001,
#  0.2332779,
#  0.1848796,
#  0.1985391,
#  0.380092,
#  0.2892162,
#  0.2671364,
#  1.519103,
#  0.357329,
#  0.1943933,
#  0.2084432,
#  0.365194,
#  0.376432,
#  11.08801,
#  0.37563599999999997,
#  0.42522499999999996,
#  0.314928,
#  0.370503,
#  0.37109899999999996,
#  0.24392350000000002,
#  0.2211745,
#  0.439774,
#  0.2079571,
#  0.2885435,
#  0.311284,
#  0.29868700000000004,
#  0.2489046,
#  0.2354502,
#  0.34422200000000003,
#  0.312668,
#  0.43127899999999997,
#  0.1926372,
#  0.246956,
#  0.2561114,
#  0.17225659999999998,
#  0.23481049999999998,
#  0.1665195,
#  0.215661,
#  0.2333268]
